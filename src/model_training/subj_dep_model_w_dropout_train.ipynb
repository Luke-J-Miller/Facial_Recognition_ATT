# %%
import numpy as np 
import os
import pandas as pd 
import tensorflow.compat.v1 as tf
import matplotlib.pyplot as plt

tf.disable_eager_execution()
import shutil
import tensorflow_hub as hub
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
from PIL import Image, ImageOps

from tensorflow.keras.layers import GlobalMaxPooling2D, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
import tensorflow.keras.optimizers
from keras.api._v2.keras.optimizers import legacy
from keras.src.optimizers.legacy.adam import Adam
import random
random.seed(42)
np.random.seed(42)
tf.random.set_random_seed(42)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def load_dataset(directory):
    def extract_label(file_path):
        """
        Extract the subject label from the file path.
        Example: '/path/to/s01/image.jpg' -> 's01'
        """
        return os.path.basename(os.path.dirname(file_path))
    images = []
    labels = []
    for folder in os.listdir(directory):
        folder_path = os.path.join(directory, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                # Load and preprocess the image
                image = load_img(file_path, target_size=(299, 299))  # Resize as per Inception V3 input
                image = img_to_array(image)
                image /= 255.0  # Normalize to [0, 1]
                
                images.append(image)
                labels.append(extract_label(file_path))

    return np.array(images), np.array(labels)

# %%
train_dir = '/kaggle/input/cs5567-final-data-processed/augmented_faces/train'
train_images, train_labels = load_dataset(train_dir)

# Convert labels to numerical format
label_to_num = {label: idx for idx, label in enumerate(np.unique(train_labels))}
num_labels = len(label_to_num)

train_labels_num = np.array([label_to_num[label] for label in train_labels])

# One-hot encode labels
train_labels_encoded = to_categorical(train_labels_num, num_classes=num_labels)

# %%
test_dir = '/kaggle/input/cs5567-final-data-processed/augmented_faces/test'
test_images, test_labels = load_dataset(train_dir)

# Convert labels to numerical format
label_to_num = {label: idx for idx, label in enumerate(np.unique(test_labels))}
num_labels = len(label_to_num)

test_labels_num = np.array([label_to_num[label] for label in test_labels])

# One-hot encode labels
test_labels_encoded = to_categorical(test_labels_num, num_classes=num_labels)

# %%
val_dir = '/kaggle/input/cs5567-final-data-processed/augmented_faces/val'
val_images, val_labels = load_dataset(val_dir)

# Convert labels to numerical format
label_to_num = {label: idx for idx, label in enumerate(np.unique(val_labels))}
num_labels = len(label_to_num)

val_labels_num = np.array([label_to_num[label] for label in val_labels])

# One-hot encode labels
val_labels_encoded = to_categorical(val_labels_num, num_classes=num_labels)

# %%
if not os.path.exists('numpy_data'):
    os.makedirs('numpy_data')

# Define the base directory path
base_dir = 'numpy_data'

# For Training Data
np.save(os.path.join(base_dir, 'train_images.npy'), train_images)
np.save(os.path.join(base_dir, 'train_labels_num.npy'), train_labels_num)
np.save(os.path.join(base_dir, 'train_labels_encoded.npy'), train_labels_encoded)

# For Test Data
np.save(os.path.join(base_dir, 'test_images.npy'), test_images)
np.save(os.path.join(base_dir, 'test_labels_num.npy'), test_labels_num)
np.save(os.path.join(base_dir, 'test_labels_encoded.npy'), test_labels_encoded)

# For Validation Data
np.save(os.path.join(base_dir, 'val_images.npy'), val_images)
np.save(os.path.join(base_dir, 'val_labels_num.npy'), val_labels_num)
np.save(os.path.join(base_dir, 'val_labels_encoded.npy'), val_labels_encoded)

# %%
base_model = InceptionV3(weights='imagenet', include_top=False)
for layer in base_model.layers:
    layer.trainable = False

model = Sequential([
    base_model,
    GlobalMaxPooling2D(),  # Changed from average to max pooling
    Dense(1024, activation='relu'),
    Dropout(0.5),  # Added dropout for regularization
    Dense(256, activation='relu'),  
    Dense(50, activation='softmax')  # Assuming 50 classes
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
for i, layer in enumerate(base_model.layers):
    print(f"Layer {i} | Name: {layer.name} | Type: {type(layer).__name__} | Trainable: {layer.trainable}")
# Out:
# Layer 0 | Name: input_1 | Type: InputLayer | Trainable: False
# Layer 1 | Name: conv2d | Type: Conv2D | Trainable: False
# Layer 2 | Name: batch_normalization | Type: BatchNormalization | Trainable: False
# Layer 3 | Name: activation | Type: Activation | Trainable: False
# Layer 4 | Name: conv2d_1 | Type: Conv2D | Trainable: False
# Layer 5 | Name: batch_normalization_1 | Type: BatchNormalization | Trainable: False
# Layer 6 | Name: activation_1 | Type: Activation | Trainable: False
# Layer 7 | Name: conv2d_2 | Type: Conv2D | Trainable: False
# Layer 8 | Name: batch_normalization_2 | Type: BatchNormalization | Trainable: False
# Layer 9 | Name: activation_2 | Type: Activation | Trainable: False
# Layer 10 | Name: max_pooling2d | Type: MaxPooling2D | Trainable: False
# Layer 11 | Name: conv2d_3 | Type: Conv2D | Trainable: False
# Layer 12 | Name: batch_normalization_3 | Type: BatchNormalization | Trainable: False
# Layer 13 | Name: activation_3 | Type: Activation | Trainable: False
# Layer 14 | Name: conv2d_4 | Type: Conv2D | Trainable: False
# Layer 15 | Name: batch_normalization_4 | Type: BatchNormalization | Trainable: False
# Layer 16 | Name: activation_4 | Type: Activation | Trainable: False
# Layer 17 | Name: max_pooling2d_1 | Type: MaxPooling2D | Trainable: False
# Layer 18 | Name: conv2d_8 | Type: Conv2D | Trainable: False
# Layer 19 | Name: batch_normalization_8 | Type: BatchNormalization | Trainable: False
# Layer 20 | Name: activation_8 | Type: Activation | Trainable: False
# Layer 21 | Name: conv2d_6 | Type: Conv2D | Trainable: False
# Layer 22 | Name: conv2d_9 | Type: Conv2D | Trainable: False
# Layer 23 | Name: batch_normalization_6 | Type: BatchNormalization | Trainable: False
# Layer 24 | Name: batch_normalization_9 | Type: BatchNormalization | Trainable: False
# Layer 25 | Name: activation_6 | Type: Activation | Trainable: False
# Layer 26 | Name: activation_9 | Type: Activation | Trainable: False
# Layer 27 | Name: average_pooling2d | Type: AveragePooling2D | Trainable: False
# Layer 28 | Name: conv2d_5 | Type: Conv2D | Trainable: False
# Layer 29 | Name: conv2d_7 | Type: Conv2D | Trainable: False
# Layer 30 | Name: conv2d_10 | Type: Conv2D | Trainable: False
# Layer 31 | Name: conv2d_11 | Type: Conv2D | Trainable: False
# Layer 32 | Name: batch_normalization_5 | Type: BatchNormalization | Trainable: False
# Layer 33 | Name: batch_normalization_7 | Type: BatchNormalization | Trainable: False
# Layer 34 | Name: batch_normalization_10 | Type: BatchNormalization | Trainable: False
# Layer 35 | Name: batch_normalization_11 | Type: BatchNormalization | Trainable: False
# Layer 36 | Name: activation_5 | Type: Activation | Trainable: False
# Layer 37 | Name: activation_7 | Type: Activation | Trainable: False
# Layer 38 | Name: activation_10 | Type: Activation | Trainable: False
# Layer 39 | Name: activation_11 | Type: Activation | Trainable: False
# Layer 40 | Name: mixed0 | Type: Concatenate | Trainable: False
# Layer 41 | Name: conv2d_15 | Type: Conv2D | Trainable: False
# Layer 42 | Name: batch_normalization_15 | Type: BatchNormalization | Trainable: False
# Layer 43 | Name: activation_15 | Type: Activation | Trainable: False
# Layer 44 | Name: conv2d_13 | Type: Conv2D | Trainable: False
# Layer 45 | Name: conv2d_16 | Type: Conv2D | Trainable: False
# Layer 46 | Name: batch_normalization_13 | Type: BatchNormalization | Trainable: False
# Layer 47 | Name: batch_normalization_16 | Type: BatchNormalization | Trainable: False
# Layer 48 | Name: activation_13 | Type: Activation | Trainable: False
# Layer 49 | Name: activation_16 | Type: Activation | Trainable: False
# Layer 50 | Name: average_pooling2d_1 | Type: AveragePooling2D | Trainable: False
# Layer 51 | Name: conv2d_12 | Type: Conv2D | Trainable: False
# Layer 52 | Name: conv2d_14 | Type: Conv2D | Trainable: False
# Layer 53 | Name: conv2d_17 | Type: Conv2D | Trainable: False
# Layer 54 | Name: conv2d_18 | Type: Conv2D | Trainable: False
# Layer 55 | Name: batch_normalization_12 | Type: BatchNormalization | Trainable: False
# Layer 56 | Name: batch_normalization_14 | Type: BatchNormalization | Trainable: False
# Layer 57 | Name: batch_normalization_17 | Type: BatchNormalization | Trainable: False
# Layer 58 | Name: batch_normalization_18 | Type: BatchNormalization | Trainable: False
# Layer 59 | Name: activation_12 | Type: Activation | Trainable: False
# Layer 60 | Name: activation_14 | Type: Activation | Trainable: False
# Layer 61 | Name: activation_17 | Type: Activation | Trainable: False
# Layer 62 | Name: activation_18 | Type: Activation | Trainable: False
# Layer 63 | Name: mixed1 | Type: Concatenate | Trainable: False
# Layer 64 | Name: conv2d_22 | Type: Conv2D | Trainable: False
# Layer 65 | Name: batch_normalization_22 | Type: BatchNormalization | Trainable: False
# Layer 66 | Name: activation_22 | Type: Activation | Trainable: False
# Layer 67 | Name: conv2d_20 | Type: Conv2D | Trainable: False
# Layer 68 | Name: conv2d_23 | Type: Conv2D | Trainable: False
# Layer 69 | Name: batch_normalization_20 | Type: BatchNormalization | Trainable: False
# Layer 70 | Name: batch_normalization_23 | Type: BatchNormalization | Trainable: False
# Layer 71 | Name: activation_20 | Type: Activation | Trainable: False
# Layer 72 | Name: activation_23 | Type: Activation | Trainable: False
# Layer 73 | Name: average_pooling2d_2 | Type: AveragePooling2D | Trainable: False
# Layer 74 | Name: conv2d_19 | Type: Conv2D | Trainable: False
# Layer 75 | Name: conv2d_21 | Type: Conv2D | Trainable: False
# Layer 76 | Name: conv2d_24 | Type: Conv2D | Trainable: False
# Layer 77 | Name: conv2d_25 | Type: Conv2D | Trainable: False
# Layer 78 | Name: batch_normalization_19 | Type: BatchNormalization | Trainable: False
# Layer 79 | Name: batch_normalization_21 | Type: BatchNormalization | Trainable: False
# Layer 80 | Name: batch_normalization_24 | Type: BatchNormalization | Trainable: False
# Layer 81 | Name: batch_normalization_25 | Type: BatchNormalization | Trainable: False
# Layer 82 | Name: activation_19 | Type: Activation | Trainable: False
# Layer 83 | Name: activation_21 | Type: Activation | Trainable: False
# Layer 84 | Name: activation_24 | Type: Activation | Trainable: False
# Layer 85 | Name: activation_25 | Type: Activation | Trainable: False
# Layer 86 | Name: mixed2 | Type: Concatenate | Trainable: False
# Layer 87 | Name: conv2d_27 | Type: Conv2D | Trainable: False
# Layer 88 | Name: batch_normalization_27 | Type: BatchNormalization | Trainable: False
# Layer 89 | Name: activation_27 | Type: Activation | Trainable: False
# Layer 90 | Name: conv2d_28 | Type: Conv2D | Trainable: False
# Layer 91 | Name: batch_normalization_28 | Type: BatchNormalization | Trainable: False
# Layer 92 | Name: activation_28 | Type: Activation | Trainable: False
# Layer 93 | Name: conv2d_26 | Type: Conv2D | Trainable: False
# Layer 94 | Name: conv2d_29 | Type: Conv2D | Trainable: False
# Layer 95 | Name: batch_normalization_26 | Type: BatchNormalization | Trainable: False
# Layer 96 | Name: batch_normalization_29 | Type: BatchNormalization | Trainable: False
# Layer 97 | Name: activation_26 | Type: Activation | Trainable: False
# Layer 98 | Name: activation_29 | Type: Activation | Trainable: False
# Layer 99 | Name: max_pooling2d_2 | Type: MaxPooling2D | Trainable: False
# Layer 100 | Name: mixed3 | Type: Concatenate | Trainable: False
# Layer 101 | Name: conv2d_34 | Type: Conv2D | Trainable: False
# Layer 102 | Name: batch_normalization_34 | Type: BatchNormalization | Trainable: False
# Layer 103 | Name: activation_34 | Type: Activation | Trainable: False
# Layer 104 | Name: conv2d_35 | Type: Conv2D | Trainable: False
# Layer 105 | Name: batch_normalization_35 | Type: BatchNormalization | Trainable: False
# Layer 106 | Name: activation_35 | Type: Activation | Trainable: False
# Layer 107 | Name: conv2d_31 | Type: Conv2D | Trainable: False
# Layer 108 | Name: conv2d_36 | Type: Conv2D | Trainable: False
# Layer 109 | Name: batch_normalization_31 | Type: BatchNormalization | Trainable: False
# Layer 110 | Name: batch_normalization_36 | Type: BatchNormalization | Trainable: False
# Layer 111 | Name: activation_31 | Type: Activation | Trainable: False
# Layer 112 | Name: activation_36 | Type: Activation | Trainable: False
# Layer 113 | Name: conv2d_32 | Type: Conv2D | Trainable: False
# Layer 114 | Name: conv2d_37 | Type: Conv2D | Trainable: False
# Layer 115 | Name: batch_normalization_32 | Type: BatchNormalization | Trainable: False
# Layer 116 | Name: batch_normalization_37 | Type: BatchNormalization | Trainable: False
# Layer 117 | Name: activation_32 | Type: Activation | Trainable: False
# Layer 118 | Name: activation_37 | Type: Activation | Trainable: False
# Layer 119 | Name: average_pooling2d_3 | Type: AveragePooling2D | Trainable: False
# Layer 120 | Name: conv2d_30 | Type: Conv2D | Trainable: False
# Layer 121 | Name: conv2d_33 | Type: Conv2D | Trainable: False
# Layer 122 | Name: conv2d_38 | Type: Conv2D | Trainable: False
# Layer 123 | Name: conv2d_39 | Type: Conv2D | Trainable: False
# Layer 124 | Name: batch_normalization_30 | Type: BatchNormalization | Trainable: False
# Layer 125 | Name: batch_normalization_33 | Type: BatchNormalization | Trainable: False
# Layer 126 | Name: batch_normalization_38 | Type: BatchNormalization | Trainable: False
# Layer 127 | Name: batch_normalization_39 | Type: BatchNormalization | Trainable: False
# Layer 128 | Name: activation_30 | Type: Activation | Trainable: False
# Layer 129 | Name: activation_33 | Type: Activation | Trainable: False
# Layer 130 | Name: activation_38 | Type: Activation | Trainable: False
# Layer 131 | Name: activation_39 | Type: Activation | Trainable: False
# Layer 132 | Name: mixed4 | Type: Concatenate | Trainable: False
# Layer 133 | Name: conv2d_44 | Type: Conv2D | Trainable: False
# Layer 134 | Name: batch_normalization_44 | Type: BatchNormalization | Trainable: False
# Layer 135 | Name: activation_44 | Type: Activation | Trainable: False
# Layer 136 | Name: conv2d_45 | Type: Conv2D | Trainable: False
# Layer 137 | Name: batch_normalization_45 | Type: BatchNormalization | Trainable: False
# Layer 138 | Name: activation_45 | Type: Activation | Trainable: False
# Layer 139 | Name: conv2d_41 | Type: Conv2D | Trainable: False
# Layer 140 | Name: conv2d_46 | Type: Conv2D | Trainable: False
# Layer 141 | Name: batch_normalization_41 | Type: BatchNormalization | Trainable: False
# Layer 142 | Name: batch_normalization_46 | Type: BatchNormalization | Trainable: False
# Layer 143 | Name: activation_41 | Type: Activation | Trainable: False
# Layer 144 | Name: activation_46 | Type: Activation | Trainable: False
# Layer 145 | Name: conv2d_42 | Type: Conv2D | Trainable: False
# Layer 146 | Name: conv2d_47 | Type: Conv2D | Trainable: False
# Layer 147 | Name: batch_normalization_42 | Type: BatchNormalization | Trainable: False
# Layer 148 | Name: batch_normalization_47 | Type: BatchNormalization | Trainable: False
# Layer 149 | Name: activation_42 | Type: Activation | Trainable: False
# Layer 150 | Name: activation_47 | Type: Activation | Trainable: False
# Layer 151 | Name: average_pooling2d_4 | Type: AveragePooling2D | Trainable: False
# Layer 152 | Name: conv2d_40 | Type: Conv2D | Trainable: False
# Layer 153 | Name: conv2d_43 | Type: Conv2D | Trainable: False
# Layer 154 | Name: conv2d_48 | Type: Conv2D | Trainable: False
# Layer 155 | Name: conv2d_49 | Type: Conv2D | Trainable: False
# Layer 156 | Name: batch_normalization_40 | Type: BatchNormalization | Trainable: False
# Layer 157 | Name: batch_normalization_43 | Type: BatchNormalization | Trainable: False
# Layer 158 | Name: batch_normalization_48 | Type: BatchNormalization | Trainable: False
# Layer 159 | Name: batch_normalization_49 | Type: BatchNormalization | Trainable: False
# Layer 160 | Name: activation_40 | Type: Activation | Trainable: False
# Layer 161 | Name: activation_43 | Type: Activation | Trainable: False
# Layer 162 | Name: activation_48 | Type: Activation | Trainable: False
# Layer 163 | Name: activation_49 | Type: Activation | Trainable: False
# Layer 164 | Name: mixed5 | Type: Concatenate | Trainable: False
# Layer 165 | Name: conv2d_54 | Type: Conv2D | Trainable: False
# Layer 166 | Name: batch_normalization_54 | Type: BatchNormalization | Trainable: False
# Layer 167 | Name: activation_54 | Type: Activation | Trainable: False
# Layer 168 | Name: conv2d_55 | Type: Conv2D | Trainable: False
# Layer 169 | Name: batch_normalization_55 | Type: BatchNormalization | Trainable: False
# Layer 170 | Name: activation_55 | Type: Activation | Trainable: False
# Layer 171 | Name: conv2d_51 | Type: Conv2D | Trainable: False
# Layer 172 | Name: conv2d_56 | Type: Conv2D | Trainable: False
# Layer 173 | Name: batch_normalization_51 | Type: BatchNormalization | Trainable: False
# Layer 174 | Name: batch_normalization_56 | Type: BatchNormalization | Trainable: False
# Layer 175 | Name: activation_51 | Type: Activation | Trainable: False
# Layer 176 | Name: activation_56 | Type: Activation | Trainable: False
# Layer 177 | Name: conv2d_52 | Type: Conv2D | Trainable: False
# Layer 178 | Name: conv2d_57 | Type: Conv2D | Trainable: False
# Layer 179 | Name: batch_normalization_52 | Type: BatchNormalization | Trainable: False
# Layer 180 | Name: batch_normalization_57 | Type: BatchNormalization | Trainable: False
# Layer 181 | Name: activation_52 | Type: Activation | Trainable: False
# Layer 182 | Name: activation_57 | Type: Activation | Trainable: False
# Layer 183 | Name: average_pooling2d_5 | Type: AveragePooling2D | Trainable: False
# Layer 184 | Name: conv2d_50 | Type: Conv2D | Trainable: False
# Layer 185 | Name: conv2d_53 | Type: Conv2D | Trainable: False
# Layer 186 | Name: conv2d_58 | Type: Conv2D | Trainable: False
# Layer 187 | Name: conv2d_59 | Type: Conv2D | Trainable: False
# Layer 188 | Name: batch_normalization_50 | Type: BatchNormalization | Trainable: False
# Layer 189 | Name: batch_normalization_53 | Type: BatchNormalization | Trainable: False
# Layer 190 | Name: batch_normalization_58 | Type: BatchNormalization | Trainable: False
# Layer 191 | Name: batch_normalization_59 | Type: BatchNormalization | Trainable: False
# Layer 192 | Name: activation_50 | Type: Activation | Trainable: False
# Layer 193 | Name: activation_53 | Type: Activation | Trainable: False
# Layer 194 | Name: activation_58 | Type: Activation | Trainable: False
# Layer 195 | Name: activation_59 | Type: Activation | Trainable: False
# Layer 196 | Name: mixed6 | Type: Concatenate | Trainable: False
# Layer 197 | Name: conv2d_64 | Type: Conv2D | Trainable: False
# Layer 198 | Name: batch_normalization_64 | Type: BatchNormalization | Trainable: False
# Layer 199 | Name: activation_64 | Type: Activation | Trainable: False
# Layer 200 | Name: conv2d_65 | Type: Conv2D | Trainable: False
# Layer 201 | Name: batch_normalization_65 | Type: BatchNormalization | Trainable: False
# Layer 202 | Name: activation_65 | Type: Activation | Trainable: False
# Layer 203 | Name: conv2d_61 | Type: Conv2D | Trainable: False
# Layer 204 | Name: conv2d_66 | Type: Conv2D | Trainable: False
# Layer 205 | Name: batch_normalization_61 | Type: BatchNormalization | Trainable: False
# Layer 206 | Name: batch_normalization_66 | Type: BatchNormalization | Trainable: False
# Layer 207 | Name: activation_61 | Type: Activation | Trainable: False
# Layer 208 | Name: activation_66 | Type: Activation | Trainable: False
# Layer 209 | Name: conv2d_62 | Type: Conv2D | Trainable: False
# Layer 210 | Name: conv2d_67 | Type: Conv2D | Trainable: False
# Layer 211 | Name: batch_normalization_62 | Type: BatchNormalization | Trainable: False
# Layer 212 | Name: batch_normalization_67 | Type: BatchNormalization | Trainable: False
# Layer 213 | Name: activation_62 | Type: Activation | Trainable: False
# Layer 214 | Name: activation_67 | Type: Activation | Trainable: False
# Layer 215 | Name: average_pooling2d_6 | Type: AveragePooling2D | Trainable: False
# Layer 216 | Name: conv2d_60 | Type: Conv2D | Trainable: False
# Layer 217 | Name: conv2d_63 | Type: Conv2D | Trainable: False
# Layer 218 | Name: conv2d_68 | Type: Conv2D | Trainable: False
# Layer 219 | Name: conv2d_69 | Type: Conv2D | Trainable: False
# Layer 220 | Name: batch_normalization_60 | Type: BatchNormalization | Trainable: False
# Layer 221 | Name: batch_normalization_63 | Type: BatchNormalization | Trainable: False
# Layer 222 | Name: batch_normalization_68 | Type: BatchNormalization | Trainable: False
# Layer 223 | Name: batch_normalization_69 | Type: BatchNormalization | Trainable: False
# Layer 224 | Name: activation_60 | Type: Activation | Trainable: False
# Layer 225 | Name: activation_63 | Type: Activation | Trainable: False
# Layer 226 | Name: activation_68 | Type: Activation | Trainable: False
# Layer 227 | Name: activation_69 | Type: Activation | Trainable: False
# Layer 228 | Name: mixed7 | Type: Concatenate | Trainable: False
# Layer 229 | Name: conv2d_72 | Type: Conv2D | Trainable: False
# Layer 230 | Name: batch_normalization_72 | Type: BatchNormalization | Trainable: False
# Layer 231 | Name: activation_72 | Type: Activation | Trainable: False
# Layer 232 | Name: conv2d_73 | Type: Conv2D | Trainable: False
# Layer 233 | Name: batch_normalization_73 | Type: BatchNormalization | Trainable: False
# Layer 234 | Name: activation_73 | Type: Activation | Trainable: False
# Layer 235 | Name: conv2d_70 | Type: Conv2D | Trainable: False
# Layer 236 | Name: conv2d_74 | Type: Conv2D | Trainable: False
# Layer 237 | Name: batch_normalization_70 | Type: BatchNormalization | Trainable: False
# Layer 238 | Name: batch_normalization_74 | Type: BatchNormalization | Trainable: False
# Layer 239 | Name: activation_70 | Type: Activation | Trainable: False
# Layer 240 | Name: activation_74 | Type: Activation | Trainable: False
# Layer 241 | Name: conv2d_71 | Type: Conv2D | Trainable: False
# Layer 242 | Name: conv2d_75 | Type: Conv2D | Trainable: False
# Layer 243 | Name: batch_normalization_71 | Type: BatchNormalization | Trainable: False
# Layer 244 | Name: batch_normalization_75 | Type: BatchNormalization | Trainable: False
# Layer 245 | Name: activation_71 | Type: Activation | Trainable: False
# Layer 246 | Name: activation_75 | Type: Activation | Trainable: False
# Layer 247 | Name: max_pooling2d_3 | Type: MaxPooling2D | Trainable: False
# Layer 248 | Name: mixed8 | Type: Concatenate | Trainable: False
# Layer 249 | Name: conv2d_80 | Type: Conv2D | Trainable: False
# Layer 250 | Name: batch_normalization_80 | Type: BatchNormalization | Trainable: False
# Layer 251 | Name: activation_80 | Type: Activation | Trainable: False
# Layer 252 | Name: conv2d_77 | Type: Conv2D | Trainable: False
# Layer 253 | Name: conv2d_81 | Type: Conv2D | Trainable: False
# Layer 254 | Name: batch_normalization_77 | Type: BatchNormalization | Trainable: False
# Layer 255 | Name: batch_normalization_81 | Type: BatchNormalization | Trainable: False
# Layer 256 | Name: activation_77 | Type: Activation | Trainable: False
# Layer 257 | Name: activation_81 | Type: Activation | Trainable: False
# Layer 258 | Name: conv2d_78 | Type: Conv2D | Trainable: False
# Layer 259 | Name: conv2d_79 | Type: Conv2D | Trainable: False
# Layer 260 | Name: conv2d_82 | Type: Conv2D | Trainable: False
# Layer 261 | Name: conv2d_83 | Type: Conv2D | Trainable: False
# Layer 262 | Name: average_pooling2d_7 | Type: AveragePooling2D | Trainable: False
# Layer 263 | Name: conv2d_76 | Type: Conv2D | Trainable: False
# Layer 264 | Name: batch_normalization_78 | Type: BatchNormalization | Trainable: False
# Layer 265 | Name: batch_normalization_79 | Type: BatchNormalization | Trainable: False
# Layer 266 | Name: batch_normalization_82 | Type: BatchNormalization | Trainable: False
# Layer 267 | Name: batch_normalization_83 | Type: BatchNormalization | Trainable: False
# Layer 268 | Name: conv2d_84 | Type: Conv2D | Trainable: False
# Layer 269 | Name: batch_normalization_76 | Type: BatchNormalization | Trainable: False
# Layer 270 | Name: activation_78 | Type: Activation | Trainable: False
# Layer 271 | Name: activation_79 | Type: Activation | Trainable: False
# Layer 272 | Name: activation_82 | Type: Activation | Trainable: False
# Layer 273 | Name: activation_83 | Type: Activation | Trainable: False
# Layer 274 | Name: batch_normalization_84 | Type: BatchNormalization | Trainable: False
# Layer 275 | Name: activation_76 | Type: Activation | Trainable: False
# Layer 276 | Name: mixed9_0 | Type: Concatenate | Trainable: False
# Layer 277 | Name: concatenate | Type: Concatenate | Trainable: False
# Layer 278 | Name: activation_84 | Type: Activation | Trainable: False
# Layer 279 | Name: mixed9 | Type: Concatenate | Trainable: False
# Layer 280 | Name: conv2d_89 | Type: Conv2D | Trainable: False
# Layer 281 | Name: batch_normalization_89 | Type: BatchNormalization | Trainable: False
# Layer 282 | Name: activation_89 | Type: Activation | Trainable: False
# Layer 283 | Name: conv2d_86 | Type: Conv2D | Trainable: False
# Layer 284 | Name: conv2d_90 | Type: Conv2D | Trainable: False
# Layer 285 | Name: batch_normalization_86 | Type: BatchNormalization | Trainable: False
# Layer 286 | Name: batch_normalization_90 | Type: BatchNormalization | Trainable: False
# Layer 287 | Name: activation_86 | Type: Activation | Trainable: False
# Layer 288 | Name: activation_90 | Type: Activation | Trainable: False
# Layer 289 | Name: conv2d_87 | Type: Conv2D | Trainable: False
# Layer 290 | Name: conv2d_88 | Type: Conv2D | Trainable: False
# Layer 291 | Name: conv2d_91 | Type: Conv2D | Trainable: False
# Layer 292 | Name: conv2d_92 | Type: Conv2D | Trainable: False
# Layer 293 | Name: average_pooling2d_8 | Type: AveragePooling2D | Trainable: False
# Layer 294 | Name: conv2d_85 | Type: Conv2D | Trainable: False
# Layer 295 | Name: batch_normalization_87 | Type: BatchNormalization | Trainable: False
# Layer 296 | Name: batch_normalization_88 | Type: BatchNormalization | Trainable: False
# Layer 297 | Name: batch_normalization_91 | Type: BatchNormalization | Trainable: False
# Layer 298 | Name: batch_normalization_92 | Type: BatchNormalization | Trainable: False
# Layer 299 | Name: conv2d_93 | Type: Conv2D | Trainable: False
# Layer 300 | Name: batch_normalization_85 | Type: BatchNormalization | Trainable: False
# Layer 301 | Name: activation_87 | Type: Activation | Trainable: False
# Layer 302 | Name: activation_88 | Type: Activation | Trainable: False
# Layer 303 | Name: activation_91 | Type: Activation | Trainable: False
# Layer 304 | Name: activation_92 | Type: Activation | Trainable: False
# Layer 305 | Name: batch_normalization_93 | Type: BatchNormalization | Trainable: False
# Layer 306 | Name: activation_85 | Type: Activation | Trainable: False
# Layer 307 | Name: mixed9_1 | Type: Concatenate | Trainable: False
# Layer 308 | Name: concatenate_1 | Type: Concatenate | Trainable: False
# Layer 309 | Name: activation_93 | Type: Activation | Trainable: False
# Layer 310 | Name: mixed10 | Type: Concatenate | Trainable: False

# %%
optimizer = Adam(learning_rate = .001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    train_images, 
    train_labels_encoded, 
    epochs=10,  # Adjust based on your requirements
    batch_size=32,  # Adjust based on your requirements
    validation_data=(val_images, val_labels_encoded)
)
# Out:
# Train on 2000 samples, validate on 100 samples
# Epoch 1/10
# 2000/2000 [==============================] - ETA: 0s - loss: 5.1122 - accuracy: 0.0255
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2000/2000 [==============================] - 23s 12ms/sample - loss: 5.1122 - accuracy: 0.0255 - val_loss: 3.9078 - val_accuracy: 0.0600
# Epoch 2/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 3.8718 - accuracy: 0.0500 - val_loss: 3.7497 - val_accuracy: 0.1200
# Epoch 3/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 3.6301 - accuracy: 0.0940 - val_loss: 3.3957 - val_accuracy: 0.2200
# Epoch 4/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 3.1870 - accuracy: 0.1715 - val_loss: 2.9030 - val_accuracy: 0.3200
# Epoch 5/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 2.8560 - accuracy: 0.2240 - val_loss: 2.4520 - val_accuracy: 0.3800
# Epoch 6/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 2.5379 - accuracy: 0.2855 - val_loss: 2.3783 - val_accuracy: 0.4000
# Epoch 7/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 2.4385 - accuracy: 0.3085 - val_loss: 2.2052 - val_accuracy: 0.3600
# Epoch 8/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 2.2183 - accuracy: 0.3515 - val_loss: 1.9128 - val_accuracy: 0.5500
# Epoch 9/10
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 2.0235 - accuracy: 0.4120 - val_loss: 1.8084 - val_accuracy: 0.5400
# Epoch 10/10
# 2000/2000 [==============================] - 11s 5ms/sample - loss: 1.9302 - accuracy: 0.4250 - val_loss: 1.8920 - val_accuracy: 0.6200

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')

plt.show()

# %%
# Unfreeze from layer 276, mixed9_0
for layer in base_model.layers[276:]:
    layer.trainable = True
optimizer = Adam(learning_rate = .0005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
history_fine_276 = model.fit(
    train_images, train_labels_encoded, 
    epochs=10,  # Adjust based on your requirements
    batch_size=32,  # Adjust based on your requirements
    validation_data=(val_images, val_labels_encoded)
)
# Out:
# Train on 2000 samples, validate on 100 samples
# Epoch 1/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 2.4834 - accuracy: 0.3180 - val_loss: 1.5510 - val_accuracy: 0.6000
# Epoch 2/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 1.4457 - accuracy: 0.5530 - val_loss: 1.0949 - val_accuracy: 0.6900
# Epoch 3/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.8965 - accuracy: 0.7140 - val_loss: 0.8133 - val_accuracy: 0.8400
# Epoch 4/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.5374 - accuracy: 0.8280 - val_loss: 0.7023 - val_accuracy: 0.8500
# Epoch 5/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.3366 - accuracy: 0.8935 - val_loss: 0.6696 - val_accuracy: 0.8600
# Epoch 6/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.2607 - accuracy: 0.9130 - val_loss: 0.6932 - val_accuracy: 0.8800
# Epoch 7/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.1974 - accuracy: 0.9375 - val_loss: 0.6403 - val_accuracy: 0.8700
# Epoch 8/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.1244 - accuracy: 0.9615 - val_loss: 0.6264 - val_accuracy: 0.9100
# Epoch 9/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.1303 - accuracy: 0.9595 - val_loss: 0.7636 - val_accuracy: 0.8800
# Epoch 10/10
# 2000/2000 [==============================] - 12s 6ms/sample - loss: 0.1243 - accuracy: 0.9615 - val_loss: 0.5824 - val_accuracy: 0.9200

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_fine_276.history['loss'], label='Training Loss')
plt.plot(history_fine_276.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history_fine_276.history['accuracy'], label='Training Accuracy')
plt.plot(history_fine_276.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')

plt.show()

# %%
# Unfreeze from layer 248, mixed8
for layer in base_model.layers[248:]:
    layer.trainable = True
optimizer = Adam(learning_rate = .0003)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
history_fine_248 = model.fit(
    train_images, train_labels_encoded, 
    epochs=10,  # Adjust based on your requirements
    batch_size=32,  # Adjust based on your requirements
    validation_data=(val_images, val_labels_encoded)
)
# Out:
# Train on 2000 samples, validate on 100 samples
# Epoch 1/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.3302 - accuracy: 0.9035 - val_loss: 0.4768 - val_accuracy: 0.9000
# Epoch 2/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.2563 - accuracy: 0.9260 - val_loss: 0.6652 - val_accuracy: 0.8600
# Epoch 3/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.1175 - accuracy: 0.9635 - val_loss: 0.6625 - val_accuracy: 0.9200
# Epoch 4/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.1086 - accuracy: 0.9670 - val_loss: 0.3362 - val_accuracy: 0.9200
# Epoch 5/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.1295 - accuracy: 0.9600 - val_loss: 0.2710 - val_accuracy: 0.9300
# Epoch 6/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.1714 - accuracy: 0.9470 - val_loss: 0.6180 - val_accuracy: 0.8500
# Epoch 7/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.1876 - accuracy: 0.9455 - val_loss: 0.2337 - val_accuracy: 0.9100
# Epoch 8/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.2069 - accuracy: 0.9425 - val_loss: 0.4587 - val_accuracy: 0.8900
# Epoch 9/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.1184 - accuracy: 0.9675 - val_loss: 0.2570 - val_accuracy: 0.9600
# Epoch 10/10
# 2000/2000 [==============================] - 13s 6ms/sample - loss: 0.0436 - accuracy: 0.9875 - val_loss: 0.3607 - val_accuracy: 0.9500

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_fine_248.history['loss'], label='Training Loss')
plt.plot(history_fine_248.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history_fine_248.history['accuracy'], label='Training Accuracy')
plt.plot(history_fine_248.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')

plt.show()

# %%
# Unfreeze from layer 228, mixed7
for layer in base_model.layers[228:]:
    layer.trainable = True
optimizer = Adam(learning_rate = .0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
history_fine_228 = model.fit(
    train_images, train_labels_encoded, 
    epochs=10,  # Adjust based on your requirements
    batch_size=32,  # Adjust based on your requirements
    validation_data=(val_images, val_labels_encoded)
)
# Out:
# Train on 2000 samples, validate on 100 samples
# Epoch 1/10
# 2000/2000 [==============================] - 16s 8ms/sample - loss: 0.0451 - accuracy: 0.9885 - val_loss: 0.2498 - val_accuracy: 0.9600
# Epoch 2/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0160 - accuracy: 0.9965 - val_loss: 0.1017 - val_accuracy: 0.9600
# Epoch 3/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0926 - val_accuracy: 0.9600
# Epoch 4/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0386 - accuracy: 0.9915 - val_loss: 0.4145 - val_accuracy: 0.9300
# Epoch 5/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0270 - accuracy: 0.9915 - val_loss: 0.4781 - val_accuracy: 0.9100
# Epoch 6/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0248 - accuracy: 0.9920 - val_loss: 0.1541 - val_accuracy: 0.9600
# Epoch 7/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0172 - accuracy: 0.9940 - val_loss: 0.1663 - val_accuracy: 0.9700
# Epoch 8/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.3382 - val_accuracy: 0.9600
# Epoch 9/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.4328 - val_accuracy: 0.9500
# Epoch 10/10
# 2000/2000 [==============================] - 14s 7ms/sample - loss: 0.0102 - accuracy: 0.9950 - val_loss: 0.3511 - val_accuracy: 0.9500

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_fine_228.history['loss'], label='Training Loss')
plt.plot(history_fine_228.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history_fine_228.history['accuracy'], label='Training Accuracy')
plt.plot(history_fine_228.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')

plt.show()

# %%
# Unfreeze from layer 196, mixed6
for layer in base_model.layers[196:]:
    layer.trainable = True
optimizer = Adam(learning_rate = .00005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
history_fine_196 = model.fit(
    train_images, train_labels_encoded, 
    epochs=10,  # Adjust based on your requirements
    batch_size=32,  # Adjust based on your requirements
    validation_data=(val_images, val_labels_encoded)
)
# Out:
# Train on 2000 samples, validate on 100 samples
# Epoch 1/10
# 2000/2000 [==============================] - 17s 9ms/sample - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.2877 - val_accuracy: 0.9700
# Epoch 2/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.3726 - val_accuracy: 0.9500
# Epoch 3/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0324 - accuracy: 0.9935 - val_loss: 0.3827 - val_accuracy: 0.9400
# Epoch 4/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.4015 - val_accuracy: 0.9700
# Epoch 5/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.4983 - val_accuracy: 0.9400
# Epoch 6/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0219 - accuracy: 0.9950 - val_loss: 0.5738 - val_accuracy: 0.9100
# Epoch 7/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0285 - accuracy: 0.9915 - val_loss: 0.3530 - val_accuracy: 0.9600
# Epoch 8/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.2002 - val_accuracy: 0.9700
# Epoch 9/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.2170 - val_accuracy: 0.9700
# Epoch 10/10
# 2000/2000 [==============================] - 15s 8ms/sample - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.2211 - val_accuracy: 0.9800

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_fine_196.history['loss'], label='Training Loss')
plt.plot(history_fine_196.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history_fine_196.history['accuracy'], label='Training Accuracy')
plt.plot(history_fine_196.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')

plt.show()

# %%
if not os.path.exists('model'):
            os.makedirs('model')
model.save('model')
